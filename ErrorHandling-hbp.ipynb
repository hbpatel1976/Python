# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
try:
    print(x)
except:
    print("An exception occurred")
# Out:
# An exception occurred

# %%
a = [1, 2, 3]
try:
  print ("Second element = %d" %(a[1]))
  print ("Fourth element = %d" %(a[3]))
except:
  print ("An error occurred")
# Out:
# Second element = 2
# An error occurred

# %%
a = 10
b = 0
print (a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-57a7363b4947> in <module>
#       1 a = 10
#       2 b = 0
# ----> 3 print (a/b)
#
# ZeroDivisionError: division by zero

# %%
a = 10
b = 0
try:
    print (a/b)
except ZeroDivisionError:
    print("Can't divide by zero")
# Out:
# Can't divide by zero

# %%
a = 10
b = 0
try:
    print (a/b)
except ZeroDivisionError:
    print("Can't divide by zero")
finally:
    print('This always gets executed')
# Out:
# Can't divide by zero
# This always gets executed

# %%
try:
    a = int(input("Enter a positive integer: "))
    if a <= 0:
        raise ValueError("That is NOT a positive number!")
    else:
        print("This is a positive number!")
except ValueError as ve:
    print(ve)
# Out:
# Enter a positive integer: 10
# This is a positive number!

# %%
file = open('sample.txt', 'r')
print('The file name is: ', file.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-8460a5c17a9e> in <module>
# ----> 1 file = open('sample.txt', 'r')
#       2 print('The file name is: ', file.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
try:
    file = open('sample.txt', 'r')
    print('File found!!!')

except IOError:
    print('File not found!!!')
# Out:
# File not found!!!

# %%
num = [3, 4, 5, 7]
try:
    if len(num) > 3:
        raise Exception(f"Length of the given list must be less than or equal to 3 but is {len(num)}")
except Exception as ex:
    print(ex)
# Out:
# Length of the given list must be less than or equal to 3 but is 4

# %%
file1 = open("myfile.txt", "w")
L = ["VSITR Kadi \n", "KSV Gandhinagar \n", "SVKM Kadi \n"]
# Writing data to a file
file1.write("Hello \n")
file1.writelines(L)
file1.close()
# check that a file "myfile.txt" has already been created

# %%
file1 = open("myfile.txt", "r+")
print("Output of Read function is ")
print(file1.read())
print()
# Out:
# Output of Read function is
# Hello
# VSITR Kadi
# KSV Gandhinagar
# SVKM Kadi

# %%
file1 = open("myfile.txt", "r+")
file1.seek(0)
print("Output of Readline function is ")
print(file1.readline())
print()
# Out:
# Output of Readline function is
# Hello

# %%
file1 = open("myfile.txt", "r+")
file1.seek(0)
print("Output of Read(9) function is ")
print(file1.read(9))
print()
# Out:
# Output of Read(9) function is
# Hello
# VS

# %%
file1 = open("myfile.txt", "r+")
file1.seek(0)
print("Output of Readlines function is ")
print(file1.readlines())
print()
# Out:
# Output of Readlines function is
# ['Hello \n', 'VSITR Kadi \n', 'KSV Gandhinagar \n', 'SVKM Kadi \n']
